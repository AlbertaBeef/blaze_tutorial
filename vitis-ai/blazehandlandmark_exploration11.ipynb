# %% [markdown]
# # Hand Landmark Detector Tutorial
# # Deploying the Hand Landmark Detector with Vitis-AI for DPU inference

# %% [markdown]
# ## Goal
#
# In this notebook we show how to deploy the BlazeHandLandmark model (a PyTorch version of the mediapipe hand-gesture)
# with Vitis-AI for deployment on the DPU. We will cover:
#
# * Create the PyTorch model and load pre-trained weights
# * Quantizing and evaluating the PyTorch model
# * Compiling for DPU using the Vitis AI compiler
#
#
# ## References
#
# * [BlazeFace-PyTorch](https://github.com/hollance/BlazeFace-PyTorch)
# * [MediaPipePytorch](https://github.com/zmurez/MediaPipePyTorch)
# * [Vitis AI v3.5](https://github.com/Xilinx/Vitis-AI/tree/v3.5)
#    * [vai_q_pytorch](https://docs.xilinx.com/r/en-US/ug1414-vitis-ai/Running-vai_q_pytorch)
#    * [vai_c_xir](https://docs.xilinx.com/r/en-US/ug1414-vitis-ai/Compiling-for-DPU)
#
#
# ## Version History
# * Jan 10, 2024
#     * Preliminary revision

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

print("OpenCV version : ",cv2.__version__)
print("PyTorch version : ",torch.__version__)
# Out:
# OpenCV version :  4.7.0
# PyTorch version :  1.13.1

# %%
# use GPU if available   
if (torch.cuda.device_count() > 0):
  print('You have',torch.cuda.device_count(),'CUDA devices available')
  for i in range(torch.cuda.device_count()):
    print(' Device',str(i),': ',torch.cuda.get_device_name(i))
  print('Selecting device 0..')
  device = torch.device('cuda:0')
else:
  print('No CUDA devices available..selecting CPU')
  device = torch.device('cpu')
# Out:
# No CUDA devices available..selecting CPU

# %% [markdown]
# # 1. Model Definition
#
# Following sections copied from the MediaPipePyTorch repository

# %% [markdown]
# # Visualization
#
# ../MediaPipePytorch/visualization.py

# %%
def draw_detections(img, detections, with_keypoints=True):
    if isinstance(detections, torch.Tensor):
        detections = detections.cpu().numpy()

    if detections.ndim == 1:
        detections = np.expand_dims(detections, axis=0)

    n_keypoints = detections.shape[1] // 2 - 2

    for i in range(detections.shape[0]):
        ymin = detections[i, 0]
        xmin = detections[i, 1]
        ymax = detections[i, 2]
        xmax = detections[i, 3]
        
        start_point = (int(xmin), int(ymin))
        end_point = (int(xmax), int(ymax))
        img = cv2.rectangle(img, start_point, end_point, (255, 0, 0), 1) 

        if with_keypoints:
            for k in range(n_keypoints):
                kp_x = int(detections[i, 4 + k*2    ])
                kp_y = int(detections[i, 4 + k*2 + 1])
                cv2.circle(img, (kp_x, kp_y), 2, (0, 0, 255), thickness=2)
    return img


def draw_roi(img, roi):
    for i in range(roi.shape[0]):
        (x1,x2,x3,x4), (y1,y2,y3,y4) = roi[i]
        cv2.line(img, (int(x1), int(y1)), (int(x2), int(y2)), (0,0,0), 2)
        cv2.line(img, (int(x1), int(y1)), (int(x3), int(y3)), (0,255,0), 2)
        cv2.line(img, (int(x2), int(y2)), (int(x4), int(y4)), (0,0,0), 2)
        cv2.line(img, (int(x3), int(y3)), (int(x4), int(y4)), (0,0,0), 2)


def draw_landmarks(img, points, connections=[], color=(0, 255, 0), size=2):
    points = points[:,:2]
    for point in points:
        x, y = point
        x, y = int(x), int(y)
        cv2.circle(img, (x, y), size, color, thickness=size)
    for connection in connections:
        x0, y0 = points[connection[0]]
        x1, y1 = points[connection[1]]
        x0, y0 = int(x0), int(y0)
        x1, y1 = int(x1), int(y1)
        cv2.line(img, (x0, y0), (x1, y1), (0,0,0), size)



# https://github.com/metalwhale/hand_tracking/blob/b2a650d61b4ab917a2367a05b85765b81c0564f2/run.py
#        8   12  16  20
#        |   |   |   |
#        7   11  15  19
#    4   |   |   |   |
#    |   6   10  14  18
#    3   |   |   |   |
#    |   5---9---13--17
#    2    \         /
#     \    \       /
#      1    \     /
#       \    \   /
#        ------0-
HAND_CONNECTIONS = [
    (0, 1), (1, 2), (2, 3), (3, 4),
    (5, 6), (6, 7), (7, 8),
    (9, 10), (10, 11), (11, 12),
    (13, 14), (14, 15), (15, 16),
    (17, 18), (18, 19), (19, 20),
    (0, 5), (5, 9), (9, 13), (13, 17), (0, 17)
]

POSE_CONNECTIONS = [
    (0,1), (1,2), (2,3), (3,7),
    (0,4), (4,5), (5,6), (6,8),
    (9,10),
    (11,13), (13,15), (15,17), (17,19), (19,15), (15,21),
    (12,14), (14,16), (16,18), (18,20), (20,16), (16,22),
    (11,12), (12,24), (24,23), (23,11)
]

# Vertex indices can be found in
# github.com/google/mediapipe/modules/face_geometry/data/canonical_face_model_uv_visualisation.png
# Found in github.com/google/mediapipe/python/solutions/face_mesh.py
FACE_CONNECTIONS = [
    # Lips.
    (61, 146), (146, 91), (91, 181), (181, 84), (84, 17),
    (17, 314), (314, 405), (405, 321), (321, 375), (375, 291),
    (61, 185), (185, 40), (40, 39), (39, 37), (37, 0),
    (0, 267), (267, 269), (269, 270), (270, 409), (409, 291),
    (78, 95), (95, 88), (88, 178), (178, 87), (87, 14),
    (14, 317), (317, 402), (402, 318), (318, 324), (324, 308),
    (78, 191), (191, 80), (80, 81), (81, 82), (82, 13),
    (13, 312), (312, 311), (311, 310), (310, 415), (415, 308),
    # Left eye.
    (263, 249), (249, 390), (390, 373), (373, 374), (374, 380),
    (380, 381), (381, 382), (382, 362), (263, 466), (466, 388),
    (388, 387), (387, 386), (386, 385), (385, 384), (384, 398),
    (398, 362),
    # Left eyebrow.
    (276, 283), (283, 282), (282, 295), (295, 285), (300, 293),
    (293, 334), (334, 296), (296, 336),
    # Right eye.
    (33, 7), (7, 163), (163, 144), (144, 145), (145, 153),
    (153, 154), (154, 155), (155, 133), (33, 246), (246, 161),
    (161, 160), (160, 159), (159, 158), (158, 157), (157, 173),
    (173, 133),
    # Right eyebrow.
    (46, 53), (53, 52), (52, 65), (65, 55), (70, 63), (63, 105),
    (105, 66), (66, 107),
    # Face oval.
    (10, 338), (338, 297), (297, 332), (332, 284), (284, 251),
    (251, 389), (389, 356), (356, 454), (454, 323), (323, 361),
    (361, 288), (288, 397), (397, 365), (365, 379), (379, 378),
    (378, 400), (400, 377), (377, 152), (152, 148), (148, 176),
    (176, 149), (149, 150), (150, 136), (136, 172), (172, 58),
    (58, 132), (132, 93), (93, 234), (234, 127), (127, 162),
    (162, 21), (21, 54), (54, 103), (103, 67), (67, 109),
    (109, 10)
]

# %% [markdown]
# ## Blaze Base
# ../MediaPipePytorch/blazebase.py

# %%
import cv2
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F


def resize_pad(img):
    """ resize and pad images to be input to the detectors

    The face and palm detector networks take 256x256 and 128x128 images
    as input. As such the input image is padded and resized to fit the
    size while maintaing the aspect ratio.

    Returns:
        img1: 256x256
        img2: 128x128
        scale: scale factor between original image and 256x256 image
        pad: pixels of padding in the original image
    """

    size0 = img.shape
    if size0[0]>=size0[1]:
        h1 = 256
        w1 = 256 * size0[1] // size0[0]
        padh = 0
        padw = 256 - w1
        scale = size0[1] / w1
    else:
        h1 = 256 * size0[0] // size0[1]
        w1 = 256
        padh = 256 - h1
        padw = 0
        scale = size0[0] / h1
    padh1 = padh//2
    padh2 = padh//2 + padh%2
    padw1 = padw//2
    padw2 = padw//2 + padw%2
    img1 = cv2.resize(img, (w1,h1))
    img1 = np.pad(img1, ((padh1, padh2), (padw1, padw2), (0,0)))
    pad = (int(padh1 * scale), int(padw1 * scale))
    img2 = cv2.resize(img1, (128,128))
    return img1, img2, scale, pad


def denormalize_detections(detections, scale, pad):
    """ maps detection coordinates from [0,1] to image coordinates

    The face and palm detector networks take 256x256 and 128x128 images
    as input. As such the input image is padded and resized to fit the
    size while maintaing the aspect ratio. This function maps the
    normalized coordinates back to the original image coordinates.

    Inputs:
        detections: nxm tensor. n is the number of detections.
            m is 4+2*k where the first 4 valuse are the bounding
            box coordinates and k is the number of additional
            keypoints output by the detector.
        scale: scalar that was used to resize the image
        pad: padding in the x and y dimensions

    """
    detections[:, 0] = detections[:, 0] * scale * 256 - pad[0]
    detections[:, 1] = detections[:, 1] * scale * 256 - pad[1]
    detections[:, 2] = detections[:, 2] * scale * 256 - pad[0]
    detections[:, 3] = detections[:, 3] * scale * 256 - pad[1]

    detections[:, 4::2] = detections[:, 4::2] * scale * 256 - pad[1]
    detections[:, 5::2] = detections[:, 5::2] * scale * 256 - pad[0]
    return detections




class BlazeBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, act='relu', skip_proj=False):
        super(BlazeBlock, self).__init__()

        self.stride = stride
        self.kernel_size = kernel_size
        self.channel_pad = out_channels - in_channels

        # TFLite uses slightly different padding than PyTorch 
        # on the depthwise conv layer when the stride is 2.
        if stride == 2:
            self.max_pool = nn.MaxPool2d(kernel_size=stride, stride=stride)
            padding = 0
        else:
            padding = (kernel_size - 1) // 2

        self.convs = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=in_channels, 
                      kernel_size=kernel_size, stride=stride, padding=padding, 
                      groups=in_channels, bias=True),
            nn.Conv2d(in_channels=in_channels, out_channels=out_channels, 
                      kernel_size=1, stride=1, padding=0, bias=True),
        )

        if skip_proj:
            self.skip_proj = nn.Conv2d(in_channels=in_channels, out_channels=out_channels, 
                      kernel_size=1, stride=1, padding=0, bias=True)
        else:
            self.skip_proj = None

        if act == 'relu':
            self.act = nn.ReLU(inplace=True)
        elif act == 'prelu':
            self.act = nn.PReLU(out_channels)
        else:
            raise NotImplementedError("unknown activation %s"%act)

    def forward(self, x):
        if self.stride == 2:
            if self.kernel_size==3:
                h = F.pad(x, (0, 2, 0, 2), "constant", 0)
            else:
                h = F.pad(x, (1, 2, 1, 2), "constant", 0)
            x = self.max_pool(x)
        else:
            h = x

        if self.skip_proj is not None:
            x = self.skip_proj(x)
        elif self.channel_pad > 0:
            x = F.pad(x, (0, 0, 0, 0, 0, self.channel_pad), "constant", 0)

        return self.act(self.convs(h) + x)


class FinalBlazeBlock(nn.Module):
    def __init__(self, channels, kernel_size=3):
        super(FinalBlazeBlock, self).__init__()

        # TFLite uses slightly different padding than PyTorch
        # on the depthwise conv layer when the stride is 2.
        self.convs = nn.Sequential(
            nn.Conv2d(in_channels=channels, out_channels=channels,
                      kernel_size=kernel_size, stride=2, padding=0,
                      groups=channels, bias=True),
            nn.Conv2d(in_channels=channels, out_channels=channels,
                      kernel_size=1, stride=1, padding=0, bias=True),
        )

        self.act = nn.ReLU(inplace=True)

    def forward(self, x):
        h = F.pad(x, (0, 2, 0, 2), "constant", 0)

        return self.act(self.convs(h))


class BlazeBase(nn.Module):
    """ Base class for media pipe models. """

    def _device(self):
        """Which device (CPU or GPU) is being used by this model?"""
        return self.classifier_8.weight.device
    
    def load_weights(self, path):
        self.load_state_dict(torch.load(path))
        self.eval()        


class BlazeLandmark(BlazeBase):
    """ Base class for landmark models. """

    def extract_roi(self, frame, xc, yc, theta, scale):

        # take points on unit square and transform them according to the roi
        points = torch.tensor([[-1, -1, 1, 1],
                            [-1, 1, -1, 1]], device=scale.device).view(1,2,4)
        points = points * scale.view(-1,1,1)/2
        theta = theta.view(-1, 1, 1)
        R = torch.cat((
            torch.cat((torch.cos(theta), -torch.sin(theta)), 2),
            torch.cat((torch.sin(theta), torch.cos(theta)), 2),
            ), 1)
        center = torch.cat((xc.view(-1,1,1), yc.view(-1,1,1)), 1)
        points = R @ points + center

        # use the points to compute the affine transform that maps 
        # these points back to the output square
        res = self.resolution
        points1 = np.array([[0, 0, res-1],
                            [0, res-1, 0]], dtype=np.float32).T
        affines = []
        imgs = []
        for i in range(points.shape[0]):
            pts = points[i, :, :3].cpu().numpy().T
            M = cv2.getAffineTransform(pts, points1)
            img = cv2.warpAffine(frame, M, (res,res))#, borderValue=127.5)
            img = torch.tensor(img, device=scale.device)
            imgs.append(img)
            affine = cv2.invertAffineTransform(M).astype('float32')
            affine = torch.tensor(affine, device=scale.device)
            affines.append(affine)
        if imgs:
            imgs = torch.stack(imgs).permute(0,3,1,2).float() / 255.#/ 127.5 - 1.0
            affines = torch.stack(affines)
        else:
            imgs = torch.zeros((0, 3, res, res), device=scale.device)
            affines = torch.zeros((0, 2, 3), device=scale.device)

        return imgs, affines, points

    def denormalize_landmarks(self, landmarks, affines):
        landmarks[:,:,:2] *= self.resolution
        for i in range(len(landmarks)):
            landmark, affine = landmarks[i], affines[i]
            landmark = (affine[:,:2] @ landmark[:,:2].T + affine[:,2:]).T
            landmarks[i,:,:2] = landmark
        return landmarks



class BlazeDetector(BlazeBase):
    """ Base class for detector models.

    Based on code from https://github.com/tkat0/PyTorch_BlazeFace/ and
    https://github.com/hollance/BlazeFace-PyTorch and
    https://github.com/google/mediapipe/
    """
    def load_anchors(self, path):
        self.anchors = torch.tensor(np.load(path), dtype=torch.float32, device=self._device())
        assert(self.anchors.ndimension() == 2)
        assert(self.anchors.shape[0] == self.num_anchors)
        assert(self.anchors.shape[1] == 4)

    def _preprocess(self, x):
        """Converts the image pixels to the range [-1, 1]."""
        return x.float() / 255.# 127.5 - 1.0

    def predict_on_image(self, img):
        """Makes a prediction on a single image.

        Arguments:
            img: a NumPy array of shape (H, W, 3) or a PyTorch tensor of
                 shape (3, H, W). The image's height and width should be 
                 128 pixels.

        Returns:
            A tensor with face detections.
        """
        if isinstance(img, np.ndarray):
            img = torch.from_numpy(img).permute((2, 0, 1))

        return self.predict_on_batch(img.unsqueeze(0))[0]

    def predict_on_batch(self, x):
        """Makes a prediction on a batch of images.

        Arguments:
            x: a NumPy array of shape (b, H, W, 3) or a PyTorch tensor of
               shape (b, 3, H, W). The height and width should be 128 pixels.

        Returns:
            A list containing a tensor of face detections for each image in 
            the batch. If no faces are found for an image, returns a tensor
            of shape (0, 17).

        Each face detection is a PyTorch tensor consisting of 17 numbers:
            - ymin, xmin, ymax, xmax
            - x,y-coordinates for the 6 keypoints
            - confidence score
        """
        if isinstance(x, np.ndarray):
            x = torch.from_numpy(x).permute((0, 3, 1, 2))

        assert x.shape[1] == 3
        assert x.shape[2] == self.y_scale
        assert x.shape[3] == self.x_scale

        # 1. Preprocess the images into tensors:
        x = x.to(self._device())
        x = self._preprocess(x)

        # 2. Run the neural network:
        with torch.no_grad():
            out = self.__call__(x)

        # 3. Postprocess the raw predictions:
        detections = self._tensors_to_detections(out[0], out[1], self.anchors)

        # 4. Non-maximum suppression to remove overlapping detections:
        filtered_detections = []
        for i in range(len(detections)):
            faces = self._weighted_non_max_suppression(detections[i])
            faces = torch.stack(faces) if len(faces) > 0 else torch.zeros((0, self.num_coords+1))
            filtered_detections.append(faces)

        return filtered_detections


    def detection2roi(self, detection):
        """ Convert detections from detector to an oriented bounding box.

        Adapted from:
        # mediapipe/modules/face_landmark/face_detection_front_detection_to_roi.pbtxt

        The center and size of the box is calculated from the center 
        of the detected box. Rotation is calcualted from the vector
        between kp1 and kp2 relative to theta0. The box is scaled
        and shifted by dscale and dy.

        """
        if self.detection2roi_method == 'box':
            # compute box center and scale
            # use mediapipe/calculators/util/detections_to_rects_calculator.cc
            xc = (detection[:,1] + detection[:,3]) / 2
            yc = (detection[:,0] + detection[:,2]) / 2
            scale = (detection[:,3] - detection[:,1]) # assumes square boxes

        elif self.detection2roi_method == 'alignment':
            # compute box center and scale
            # use mediapipe/calculators/util/alignment_points_to_rects_calculator.cc
            xc = detection[:,4+2*self.kp1]
            yc = detection[:,4+2*self.kp1+1]
            x1 = detection[:,4+2*self.kp2]
            y1 = detection[:,4+2*self.kp2+1]
            scale = ((xc-x1)**2 + (yc-y1)**2).sqrt() * 2
        else:
            raise NotImplementedError(
                "detection2roi_method [%s] not supported"%self.detection2roi_method)

        yc += self.dy * scale
        scale *= self.dscale

        # compute box rotation
        x0 = detection[:,4+2*self.kp1]
        y0 = detection[:,4+2*self.kp1+1]
        x1 = detection[:,4+2*self.kp2]
        y1 = detection[:,4+2*self.kp2+1]
        #theta = np.arctan2(y0-y1, x0-x1) - self.theta0
        theta = torch.atan2(y0-y1, x0-x1) - self.theta0
        return xc, yc, scale, theta


    def _tensors_to_detections(self, raw_box_tensor, raw_score_tensor, anchors):
        """The output of the neural network is a tensor of shape (b, 896, 16)
        containing the bounding box regressor predictions, as well as a tensor 
        of shape (b, 896, 1) with the classification confidences.

        This function converts these two "raw" tensors into proper detections.
        Returns a list of (num_detections, 17) tensors, one for each image in
        the batch.

        This is based on the source code from:
        mediapipe/calculators/tflite/tflite_tensors_to_detections_calculator.cc
        mediapipe/calculators/tflite/tflite_tensors_to_detections_calculator.proto
        """
        assert raw_box_tensor.ndimension() == 3
        assert raw_box_tensor.shape[1] == self.num_anchors
        assert raw_box_tensor.shape[2] == self.num_coords

        assert raw_score_tensor.ndimension() == 3
        assert raw_score_tensor.shape[1] == self.num_anchors
        assert raw_score_tensor.shape[2] == self.num_classes

        assert raw_box_tensor.shape[0] == raw_score_tensor.shape[0]
        
        detection_boxes = self._decode_boxes(raw_box_tensor, anchors)
        
        thresh = self.score_clipping_thresh
        raw_score_tensor = raw_score_tensor.clamp(-thresh, thresh)
        detection_scores = raw_score_tensor.sigmoid().squeeze(dim=-1)
        
        # Note: we stripped off the last dimension from the scores tensor
        # because there is only has one class. Now we can simply use a mask
        # to filter out the boxes with too low confidence.
        mask = detection_scores >= self.min_score_thresh

        # Because each image from the batch can have a different number of
        # detections, process them one at a time using a loop.
        output_detections = []
        for i in range(raw_box_tensor.shape[0]):
            boxes = detection_boxes[i, mask[i]]
            scores = detection_scores[i, mask[i]].unsqueeze(dim=-1)
            output_detections.append(torch.cat((boxes, scores), dim=-1))

        return output_detections

    def _decode_boxes(self, raw_boxes, anchors):
        """Converts the predictions into actual coordinates using
        the anchor boxes. Processes the entire batch at once.
        """
        boxes = torch.zeros_like(raw_boxes)

        x_center = raw_boxes[..., 0] / self.x_scale * anchors[:, 2] + anchors[:, 0]
        y_center = raw_boxes[..., 1] / self.y_scale * anchors[:, 3] + anchors[:, 1]

        w = raw_boxes[..., 2] / self.w_scale * anchors[:, 2]
        h = raw_boxes[..., 3] / self.h_scale * anchors[:, 3]

        boxes[..., 0] = y_center - h / 2.  # ymin
        boxes[..., 1] = x_center - w / 2.  # xmin
        boxes[..., 2] = y_center + h / 2.  # ymax
        boxes[..., 3] = x_center + w / 2.  # xmax

        for k in range(self.num_keypoints):
            offset = 4 + k*2
            keypoint_x = raw_boxes[..., offset    ] / self.x_scale * anchors[:, 2] + anchors[:, 0]
            keypoint_y = raw_boxes[..., offset + 1] / self.y_scale * anchors[:, 3] + anchors[:, 1]
            boxes[..., offset    ] = keypoint_x
            boxes[..., offset + 1] = keypoint_y

        return boxes

    def _weighted_non_max_suppression(self, detections):
        """The alternative NMS method as mentioned in the BlazeFace paper:

        "We replace the suppression algorithm with a blending strategy that
        estimates the regression parameters of a bounding box as a weighted
        mean between the overlapping predictions."

        The original MediaPipe code assigns the score of the most confident
        detection to the weighted detection, but we take the average score
        of the overlapping detections.

        The input detections should be a Tensor of shape (count, 17).

        Returns a list of PyTorch tensors, one for each detected face.
        
        This is based on the source code from:
        mediapipe/calculators/util/non_max_suppression_calculator.cc
        mediapipe/calculators/util/non_max_suppression_calculator.proto
        """
        if len(detections) == 0: return []

        output_detections = []

        # Sort the detections from highest to lowest score.
        remaining = torch.argsort(detections[:, self.num_coords], descending=True)

        while len(remaining) > 0:
            detection = detections[remaining[0]]

            # Compute the overlap between the first box and the other 
            # remaining boxes. (Note that the other_boxes also include
            # the first_box.)
            first_box = detection[:4]
            other_boxes = detections[remaining, :4]
            ious = overlap_similarity(first_box, other_boxes)

            # If two detections don't overlap enough, they are considered
            # to be from different faces.
            mask = ious > self.min_suppression_threshold
            overlapping = remaining[mask]
            remaining = remaining[~mask]

            # Take an average of the coordinates from the overlapping
            # detections, weighted by their confidence scores.
            weighted_detection = detection.clone()
            if len(overlapping) > 1:
                coordinates = detections[overlapping, :self.num_coords]
                scores = detections[overlapping, self.num_coords:self.num_coords+1]
                total_score = scores.sum()
                weighted = (coordinates * scores).sum(dim=0) / total_score
                weighted_detection[:self.num_coords] = weighted
                weighted_detection[self.num_coords] = total_score / len(overlapping)

            output_detections.append(weighted_detection)

        return output_detections    


# IOU code from https://github.com/amdegroot/ssd.pytorch/blob/master/layers/box_utils.py

def intersect(box_a, box_b):
    """ We resize both tensors to [A,B,2] without new malloc:
    [A,2] -> [A,1,2] -> [A,B,2]
    [B,2] -> [1,B,2] -> [A,B,2]
    Then we compute the area of intersect between box_a and box_b.
    Args:
      box_a: (tensor) bounding boxes, Shape: [A,4].
      box_b: (tensor) bounding boxes, Shape: [B,4].
    Return:
      (tensor) intersection area, Shape: [A,B].
    """
    A = box_a.size(0)
    B = box_b.size(0)
    max_xy = torch.min(box_a[:, 2:].unsqueeze(1).expand(A, B, 2),
                       box_b[:, 2:].unsqueeze(0).expand(A, B, 2))
    min_xy = torch.max(box_a[:, :2].unsqueeze(1).expand(A, B, 2),
                       box_b[:, :2].unsqueeze(0).expand(A, B, 2))
    inter = torch.clamp((max_xy - min_xy), min=0)
    return inter[:, :, 0] * inter[:, :, 1]


def jaccard(box_a, box_b):
    """Compute the jaccard overlap of two sets of boxes.  The jaccard overlap
    is simply the intersection over union of two boxes.  Here we operate on
    ground truth boxes and default boxes.
    E.g.:
        A ∩ B / A ∪ B = A ∩ B / (area(A) + area(B) - A ∩ B)
    Args:
        box_a: (tensor) Ground truth bounding boxes, Shape: [num_objects,4]
        box_b: (tensor) Prior boxes from priorbox layers, Shape: [num_priors,4]
    Return:
        jaccard overlap: (tensor) Shape: [box_a.size(0), box_b.size(0)]
    """
    inter = intersect(box_a, box_b)
    area_a = ((box_a[:, 2]-box_a[:, 0]) *
              (box_a[:, 3]-box_a[:, 1])).unsqueeze(1).expand_as(inter)  # [A,B]
    area_b = ((box_b[:, 2]-box_b[:, 0]) *
              (box_b[:, 3]-box_b[:, 1])).unsqueeze(0).expand_as(inter)  # [A,B]
    union = area_a + area_b - inter
    return inter / union  # [A,B]


def overlap_similarity(box, other_boxes):
    """Computes the IOU between a bounding box and set of other boxes."""
    return jaccard(box.unsqueeze(0), other_boxes).squeeze(0)

# %% [markdown]
# ## Base Palm
# ../MediaPipePytorch/blazepalm.py

# %%
class BlazePalm(BlazeDetector):
    """The palm detection model from MediaPipe. """
    def __init__(self):
        super(BlazePalm, self).__init__()

        # These are the settings from the MediaPipe example graph
        # mediapipe/graphs/hand_tracking/subgraphs/hand_detection_gpu.pbtxt
        self.num_classes = 1
        self.num_anchors = 2944
        self.num_coords = 18
        self.score_clipping_thresh = 100.0
        self.x_scale = 256.0
        self.y_scale = 256.0
        self.h_scale = 256.0
        self.w_scale = 256.0
        self.min_score_thresh = 0.5
        self.min_suppression_threshold = 0.3
        self.num_keypoints = 7

        # These settings are for converting detections to ROIs which can then
        # be extracted and feed into the landmark network
        # use mediapipe/calculators/util/detections_to_rects_calculator.cc
        self.detection2roi_method = 'box'
        # mediapipe/graphs/hand_tracking/subgraphs/hand_detection_cpu.pbtxt
        self.kp1 = 0
        self.kp2 = 2
        self.theta0 = np.pi/2
        self.dscale = 2.6
        self.dy = -0.5

        self._define_layers()

    def _define_layers(self):
        self.backbone1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.ReLU(inplace=True),

            BlazeBlock(32, 32),
            BlazeBlock(32, 32),
            BlazeBlock(32, 32),
            BlazeBlock(32, 32),
            BlazeBlock(32, 32),
            BlazeBlock(32, 32),
            BlazeBlock(32, 32),
            
            BlazeBlock(32, 64, stride=2),
            BlazeBlock(64, 64),
            BlazeBlock(64, 64),
            BlazeBlock(64, 64),
            BlazeBlock(64, 64),
            BlazeBlock(64, 64),
            BlazeBlock(64, 64),
            BlazeBlock(64, 64),

            BlazeBlock(64, 128, stride=2),
            BlazeBlock(128, 128),
            BlazeBlock(128, 128),
            BlazeBlock(128, 128),
            BlazeBlock(128, 128),
            BlazeBlock(128, 128),
            BlazeBlock(128, 128),
            BlazeBlock(128, 128),

        )
        
        self.backbone2 = nn.Sequential(
            BlazeBlock(128, 256, stride=2),
            BlazeBlock(256, 256),
            BlazeBlock(256, 256),
            BlazeBlock(256, 256),
            BlazeBlock(256, 256),
            BlazeBlock(256, 256),
            BlazeBlock(256, 256),
            BlazeBlock(256, 256),
        )

        self.backbone3 = nn.Sequential(
            BlazeBlock(256, 256, stride=2),
            BlazeBlock(256, 256),
            BlazeBlock(256, 256),
            BlazeBlock(256, 256),
            BlazeBlock(256, 256),
            BlazeBlock(256, 256),
            BlazeBlock(256, 256),
            BlazeBlock(256, 256),
        )

        self.conv_transpose1 = nn.ConvTranspose2d(in_channels=256, out_channels=256, kernel_size=2, stride=2, padding=0, bias=True)
        self.blaze1 = BlazeBlock(256, 256)

        self.conv_transpose2 = nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=2, stride=2, padding=0, bias=True)
        self.blaze2 = BlazeBlock(128, 128)

        self.classifier_32 = nn.Conv2d(128, 2, 1, bias=True)
        self.classifier_16 = nn.Conv2d(256, 2, 1, bias=True)
        self.classifier_8 = nn.Conv2d(256, 6, 1, bias=True)
        
        self.regressor_32 = nn.Conv2d(128, 36, 1, bias=True)
        self.regressor_16 = nn.Conv2d(256, 36, 1, bias=True)
        self.regressor_8 = nn.Conv2d(256, 108, 1, bias=True)
        
    def forward(self, x):
        b = x.shape[0]      # batch size, needed for reshaping later

        x = F.pad(x, (0, 1, 0, 1), "constant", 0)

        x = self.backbone1(x)           # (b, 128, 32, 32)        
        y = self.backbone2(x)           # (b, 256, 16, 16)
        z = self.backbone3(y)           # (b, 256, 8, 8)

        y = y + F.relu(self.conv_transpose1(z), True)
        y = self.blaze1(y)

        x = x + F.relu(self.conv_transpose2(y), True)
        x = self.blaze2(x)


        # Note: Because PyTorch is NCHW but TFLite is NHWC, we need to
        # permute the output from the conv layers before reshaping it.
        
        c1 = self.classifier_8(z)       # (b, 2, 16, 16)
        c1 = c1.permute(0, 2, 3, 1)     # (b, 16, 16, 2)
        c1 = c1.reshape(b, -1, 1)       # (b, 512, 1)

        c2 = self.classifier_16(y)      # (b, 6, 8, 8)
        c2 = c2.permute(0, 2, 3, 1)     # (b, 8, 8, 6)
        c2 = c2.reshape(b, -1, 1)       # (b, 384, 1)

        c3 = self.classifier_32(x)      # (b, 6, 8, 8)
        c3 = c3.permute(0, 2, 3, 1)     # (b, 8, 8, 6)
        c3 = c3.reshape(b, -1, 1)       # (b, 384, 1)

        c = torch.cat((c3, c2, c1), dim=1)  # (b, 896, 1)

        r1 = self.regressor_8(z)        # (b, 32, 16, 16)
        r1 = r1.permute(0, 2, 3, 1)     # (b, 16, 16, 32)
        r1 = r1.reshape(b, -1, 18)      # (b, 512, 16)

        r2 = self.regressor_16(y)       # (b, 96, 8, 8)
        r2 = r2.permute(0, 2, 3, 1)     # (b, 8, 8, 96)
        r2 = r2.reshape(b, -1, 18)      # (b, 384, 16)

        r3 = self.regressor_32(x)       # (b, 96, 8, 8)
        r3 = r3.permute(0, 2, 3, 1)     # (b, 8, 8, 96)
        r3 = r3.reshape(b, -1, 18)      # (b, 384, 16)

        r = torch.cat((r3, r2, r1), dim=1)  # (b, 896, 16)

        return [r, c]

# %% [markdown]
# ## Base Hand Langmark
# ../MediaPipePytorch/blazehand_landmark.py

# %%
class BlazeHandLandmark(BlazeLandmark):
    """The hand landmark model from MediaPipe.
    
    """
    def __init__(self):
        super(BlazeHandLandmark, self).__init__()

        # size of ROIs used for input
        self.resolution = 256

        self._define_layers()

    def _define_layers(self):
        self.backbone1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=24, kernel_size=3, stride=2, padding=0, bias=True),
            nn.ReLU(inplace=True),

            BlazeBlock(24, 24, 5),
            BlazeBlock(24, 24, 5),
            BlazeBlock(24, 48, 5, 2),
        )

        self.backbone2 = nn.Sequential(
            BlazeBlock(48, 48, 5),
            BlazeBlock(48, 48, 5),
            BlazeBlock(48, 96, 5, 2),
        )

        self.backbone3 = nn.Sequential(
            BlazeBlock(96, 96, 5),
            BlazeBlock(96, 96, 5),
            BlazeBlock(96, 96, 5, 2),
        )

        self.backbone4 = nn.Sequential(
            BlazeBlock(96, 96, 5),
            BlazeBlock(96, 96, 5),
            BlazeBlock(96, 96, 5, 2),
        )

        self.blaze5 = BlazeBlock(96, 96, 5)
        self.blaze6 = BlazeBlock(96, 96, 5)
        self.conv7 = nn.Conv2d(96, 48, 1, bias=True)

        self.backbone8 = nn.Sequential(
            BlazeBlock(48, 48, 5),
            BlazeBlock(48, 48, 5),
            BlazeBlock(48, 48, 5),
            BlazeBlock(48, 48, 5),
            BlazeBlock(48, 96, 5, 2),
            BlazeBlock(96, 96, 5),
            BlazeBlock(96, 96, 5),
            BlazeBlock(96, 96, 5),
            BlazeBlock(96, 96, 5),
            BlazeBlock(96, 288, 5, 2),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5, 2),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5, 2),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5, 2),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5),
            BlazeBlock(288, 288, 5),
        )

        self.hand_flag = nn.Conv2d(288, 1, 2, bias=True)
        self.handed = nn.Conv2d(288, 1, 2, bias=True)
        self.landmarks = nn.Conv2d(288, 63, 2, bias=True)


    def forward(self, x):
        if x.shape[0] == 0:
            return torch.zeros((0,)), torch.zeros((0,)), torch.zeros((0, 21, 3))

        x = F.pad(x, (0, 1, 0, 1), "constant", 0)

        x = self.backbone1(x)
        y = self.backbone2(x)
        z = self.backbone3(y)
        w = self.backbone4(z)

        z = z + F.interpolate(w, scale_factor=2, mode='bilinear')
        z = self.blaze5(z)

        y = y + F.interpolate(z, scale_factor=2, mode='bilinear')
        y = self.blaze6(y)
        y = self.conv7(y)

        x = x + F.interpolate(y, scale_factor=2, mode='bilinear')

        x = self.backbone8(x)

        hand_flag = self.hand_flag(x).view(-1).sigmoid()
        handed = self.handed(x).view(-1).sigmoid()
        landmarks = self.landmarks(x).view(-1, 21, 3) / 256

        return hand_flag, handed, landmarks

# %% [markdown]
# ## Model Instantiation
# ../MediaPipePytorch/demo.py

# %%
model_palm = BlazePalm().to(device)
model_palm.load_weights("../MediaPipePyTorch/blazepalm.pth")
model_palm.load_anchors('../MediaPipePyTorch/anchors_palm.npy')
model_palm.min_score_thresh = .75
#model_palm.eval()

model = BlazeHandLandmark().to(device)
model.load_weights("../MediaPipePyTorch/blazehand_landmark.pth")
model.eval()
# Out:
# BlazeHandLandmark(
#   (backbone1): Sequential(
#     (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=24)
#         (1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (3): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=24)
#         (1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (4): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(5, 5), stride=(2, 2), groups=24)
#         (1): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#   )
#   (backbone2): Sequential(
#     (0): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(48, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=48)
#         (1): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (1): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(48, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=48)
#         (1): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (2): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(48, 48, kernel_size=(5, 5), stride=(2, 2), groups=48)
#         (1): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#   )
#   (backbone3): Sequential(
#     (0): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96)
#         (1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (1): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96)
#         (1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (2): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), groups=96)
#         (1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#   )
#   (backbone4): Sequential(
#     (0): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96)
#         (1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (1): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96)
#         (1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (2): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), groups=96)
#         (1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#   )
#   (blaze5): BlazeBlock(
#     (convs): Sequential(
#       (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96)
#       (1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (act): ReLU(inplace=True)
#   )
#   (blaze6): BlazeBlock(
#     (convs): Sequential(
#       (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96)
#       (1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (act): ReLU(inplace=True)
#   )
#   (conv7): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1))
#   (backbone8): Sequential(
#     (0): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(48, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=48)
#         (1): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (1): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(48, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=48)
#         (1): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (2): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(48, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=48)
#         (1): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (3): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(48, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=48)
#         (1): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (4): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(48, 48, kernel_size=(5, 5), stride=(2, 2), groups=48)
#         (1): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (5): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96)
#         (1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (6): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96)
#         (1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (7): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96)
#         (1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (8): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96)
#         (1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (9): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), groups=96)
#         (1): Conv2d(96, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (10): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (11): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (12): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (13): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (14): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (15): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (16): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (17): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (18): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (19): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (20): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (21): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (22): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (23): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (24): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (25): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (26): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (27): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#     (28): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288)
#         (1): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): ReLU(inplace=True)
#     )
#   )
#   (hand_flag): Conv2d(288, 1, kernel_size=(2, 2), stride=(1, 1))
#   (handed): Conv2d(288, 1, kernel_size=(2, 2), stride=(1, 1))
#   (landmarks): Conv2d(288, 63, kernel_size=(2, 2), stride=(1, 1))
# )

# %%
#!ls ../captured-images
#filename='../captured-images/frame0110_asl00.tif'
#filename='../captured-images/frame0139_asl01.tif'
#filename='../captured-images/frame0159_asl11.tif'
#filename='../captured-images/frame0177_asl17.tif'
#filename='../captured-images/frame0383_asl28.tif'
#filename='../captured-images/frame0655_asl26.tif'
#filename='../captured-images/frame6925_asl24.tif'

# %%
# reference : https://colab.research.google.com/github/googlesamples/mediapipe/blob/main/examples/hand_landmarker/python/hand_landmarker.ipynb
#!wget -q -O image.jpg https://storage.googleapis.com/mediapipe-tasks/hand_landmarker/woman_hands.jpg
#filename = "image.jpg"

# %%
filename = "image_neo_1hand.png"

# %%
import cv2
# %matplotlib inline
from matplotlib import pyplot as plt

frame = cv2.imread(filename)
print(frame.shape)
frame = np.ascontiguousarray(frame[:,:,::-1])
print(frame.shape)
hh, ww, _ = frame.shape
ll = min(hh, ww)
#img = cv2.resize(frame[:ll, :ll][:, ::-1], (256, 256))
#img = cv2.resize(frame, (256, 256))
#print(img.shape)
#print(isinstance(img, np.ndarray))
img1, img2, scale, pad = resize_pad(frame)
print(img1.shape,img2.shape,scale,pad)
normalized_palm_detections = model_palm.predict_on_image(img1)
print(normalized_palm_detections)
palm_detections = denormalize_detections(normalized_palm_detections, scale, pad)
print(palm_detections)

xc, yc, scale, theta = model_palm.detection2roi(palm_detections.cpu())
img, affine2, box2 = model.extract_roi(frame, xc, yc, theta, scale)
print(img.shape,affine2.shape,box2.shape)
flags2, handed2, normalized_landmarks2 = model(img.to(device))
landmarks2 = model.denormalize_landmarks(normalized_landmarks2.cpu(), affine2)
    
for i in range(len(flags2)):
    landmark, flag = landmarks2[i], flags2[i]
    #print(flags2[i],handed2[i],landmarks2[i])
    #if flag>.5:
    if flag>.3:
        draw_landmarks(frame, landmark[:,:2], HAND_CONNECTIONS, size=2)

draw_roi(frame, box2)
draw_detections(frame, palm_detections)


plt.imshow(frame)
plt.show()
# Out:
# (665, 956, 3)
# (665, 956, 3)
# (256, 256, 3) (128, 128, 3) 3.735955056179775 (145, 0)
# tensor([[0.4289, 0.4201, 0.4924, 0.4836, 0.4542, 0.4894, 0.4614, 0.4376, 0.4464,
#          0.4397, 0.4333, 0.4451, 0.4226, 0.4521, 0.4709, 0.4803, 0.4755, 0.4573,
#          0.9257]])
# tensor([[265.1979, 401.8243, 325.9200, 462.5465, 434.3639, 323.0363, 441.3094,
#          273.4822, 426.8966, 275.4972, 414.3666, 280.6848, 404.1408, 287.3489,
#          450.3781, 314.3741, 454.7672, 292.3215, 885.3578]])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 2, 3]) torch.Size([1, 2, 4])

# %%
import cv2
cap = cv2.VideoCapture(0)
# Out:
# [ WARN:0@1.883] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@1.884] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range

# %% [markdown]
# ## 2. Inspection
# In order to determine if the model is supported by Vitis-AI, we start with the Vitis-AI Inspector.

# %%
from pytorch_nndct.apis import Inspector
# Out:
# [VAIQ_NOTE]: Loading NNDCT kernels...
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'

# %%
inspector = Inspector("DPUCZDX8G_ISA1_B4096")
batchsize = 1
rand_in = torch.randn([batchsize, 3,256,256])
inspector.inspect(model, (rand_in), device=device)
# Out:
# [VAIQ_NOTE]: Inspector is on.
#
# [VAIQ_NOTE]: =>Start to inspect model...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cpu'.
#
# [VAIQ_NOTE]: =>Parsing BlazeHandLandmark...
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model nndct_st_BlazeHandLandmark_ed is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 216/216 [00:00<00:00, 939.34
# [VAIQ_NOTE]: =>Doing weights equalization...
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(quantize_result/BlazeHandLandmark.py)
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/ret.5) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone1]/BlazeBlock[4]/ret.21) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone2]/BlazeBlock[2]/ret.43) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone3]/BlazeBlock[2]/ret.65) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone4]/BlazeBlock[2]/ret.85) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[4]/ret.143) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[9]/ret.177) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[14]/ret.211) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[19]/ret.243) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[24]/ret.275) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[9]/ret.179) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[4]/ret.145) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone2]/BlazeBlock[2]/ret.45) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone1]/BlazeBlock[4]/ret.23) can't be fused
#
# [VAIQ_NOTE]: Find subgraph for convlike_fix_18:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone1]/Conv2d[0]/ret.7, op type:nndct_conv2d, output shape: [1, 128, 128, 24]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone1]/ReLU[1]/13516, op type:nndct_relu, output shape: [1, 128, 128, 24]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone4]/BlazeBlock[2]/ret.91, op type:nndct_elemwise_add, output shape: [1, 8, 8, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone4]/BlazeBlock[2]/ReLU[act]/14166, op type:nndct_relu, output shape: [1, 8, 8, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/BlazeBlock[blaze6]/ret.111, op type:nndct_elemwise_add, output shape: [1, 32, 32, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/BlazeBlock[blaze6]/ReLU[act]/14274, op type:nndct_relu, output shape: [1, 32, 32, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[8]/ret.175, op type:nndct_elemwise_add, output shape: [1, 32, 32, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[8]/ReLU[act]/14736, op type:nndct_relu, output shape: [1, 32, 32, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[28]/ret.305, op type:nndct_elemwise_add, output shape: [1, 2, 2, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[28]/ReLU[act]/15727, op type:nndct_relu, output shape: [1, 2, 2, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[6]/ret.163, op type:nndct_elemwise_add, output shape: [1, 32, 32, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[6]/ReLU[act]/14648, op type:nndct_relu, output shape: [1, 32, 32, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/BlazeBlock[blaze5]/ret.101, op type:nndct_elemwise_add, output shape: [1, 16, 16, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/BlazeBlock[blaze5]/ReLU[act]/14220, op type:nndct_relu, output shape: [1, 16, 16, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[27]/ret.299, op type:nndct_elemwise_add, output shape: [1, 2, 2, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[27]/ReLU[act]/15683, op type:nndct_relu, output shape: [1, 2, 2, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone2]/BlazeBlock[1]/ret.41, op type:nndct_elemwise_add, output shape: [1, 64, 64, 48]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone2]/BlazeBlock[1]/ReLU[act]/13772, op type:nndct_relu, output shape: [1, 64, 64, 48]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone4]/BlazeBlock[0]/ret.77, op type:nndct_elemwise_add, output shape: [1, 16, 16, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone4]/BlazeBlock[0]/ReLU[act]/14053, op type:nndct_relu, output shape: [1, 16, 16, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[14]/ret.217, op type:nndct_elemwise_add, output shape: [1, 8, 8, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[14]/ReLU[act]/15061, op type:nndct_relu, output shape: [1, 8, 8, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[17]/ret.235, op type:nndct_elemwise_add, output shape: [1, 8, 8, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[17]/ReLU[act]/15193, op type:nndct_relu, output shape: [1, 8, 8, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[24]/ret.281, op type:nndct_elemwise_add, output shape: [1, 2, 2, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[24]/ReLU[act]/15551, op type:nndct_relu, output shape: [1, 2, 2, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[22]/ret.267, op type:nndct_elemwise_add, output shape: [1, 4, 4, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[22]/ReLU[act]/15438, op type:nndct_relu, output shape: [1, 4, 4, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[4]/ret.151, op type:nndct_elemwise_add, output shape: [1, 32, 32, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[4]/ReLU[act]/14560, op type:nndct_relu, output shape: [1, 32, 32, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[26]/ret.293, op type:nndct_elemwise_add, output shape: [1, 2, 2, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[26]/ReLU[act]/15639, op type:nndct_relu, output shape: [1, 2, 2, 288]
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I20240114 12:05:55.150820   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.150842   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.150853   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.150915   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_conv2d_nndct_relu_JX6mE3v2dyI0ZK1Y, with op num: 9
# I20240114 12:05:55.150919   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.154892   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20240114 12:05:55.154917   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.170336   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.170356   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.170361   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.170430   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_fqmEsY8gCubU1IN5, with op num: 7
# I20240114 12:05:55.170434   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.173435   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.173465   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.176978   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.176996   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.176999   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.177060   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_nVGOiPrRYbCz6JxE, with op num: 7
# I20240114 12:05:55.177063   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.180343   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.180372   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.183200   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.183215   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.183220   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.183283   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_lfCqxOku8Zw4z9Lg, with op num: 7
# I20240114 12:05:55.183286   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.186291   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.186318   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.188864   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.188879   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.188881   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.188936   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_3sRm65N8ZrCb0qiJ, with op num: 7
# I20240114 12:05:55.188941   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.191742   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.191766   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.194586   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.194598   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.194602   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.194658   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_01PskgqJnFTSl5Hj, with op num: 7
# I20240114 12:05:55.194662   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.198427   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.198459   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.202138   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.202158   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.202162   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.202231   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_oKbjgrnR76pA12BP, with op num: 7
# I20240114 12:05:55.202234   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.205196   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.205225   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.207990   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.208006   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.208009   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.208071   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_dLU1KnqbcEZySNwf, with op num: 7
# I20240114 12:05:55.208074   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.210944   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.210968   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.214074   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.214097   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.214102   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.214182   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_HnIPMpuovWiYq12Z, with op num: 7
# I20240114 12:05:55.214188   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.219147   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.219194   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.222266   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.222285   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.222290   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.222355   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_Yxzq1WgM9mA05cXI, with op num: 7
# I20240114 12:05:55.222359   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.225327   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.225353   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.227983   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.227998   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.228003   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.228075   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_kiPOzDAJXbCQKcBM, with op num: 7
# I20240114 12:05:55.228080   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.230979   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.231004   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.233656   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.233670   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.233675   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.233731   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_ulgh1sT3Q42NVczX, with op num: 7
# I20240114 12:05:55.233734   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.236918   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.236945   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.239670   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.239684   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.239688   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.239744   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_X50eFN4PJux9VdQK, with op num: 7
# I20240114 12:05:55.239748   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.242596   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.242619   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.245107   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.245121   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.245124   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.245172   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_aFrxkzNh9RBvdHlD, with op num: 7
# I20240114 12:05:55.245177   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.249589   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.249632   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.253268   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.253288   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.253291   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.253357   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_ZCmGoqwWXHjLQiKl, with op num: 7
# I20240114 12:05:55.253361   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.256485   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.256515   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[0]/ret.123, op type:nndct_elemwise_add, output shape: [1, 64, 64, 48]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[0]/ReLU[act]/14348, op type:nndct_relu, output shape: [1, 64, 64, 48]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[20]/ret.255, op type:nndct_elemwise_add, output shape: [1, 4, 4, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[20]/ReLU[act]/15350, op type:nndct_relu, output shape: [1, 4, 4, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone3]/BlazeBlock[0]/ret.57, op type:nndct_elemwise_add, output shape: [1, 32, 32, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone3]/BlazeBlock[0]/ReLU[act]/13896, op type:nndct_relu, output shape: [1, 32, 32, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone4]/BlazeBlock[1]/ret.83, op type:nndct_elemwise_add, output shape: [1, 16, 16, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone4]/BlazeBlock[1]/ReLU[act]/14097, op type:nndct_relu, output shape: [1, 16, 16, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[3]/ret.141, op type:nndct_elemwise_add, output shape: [1, 64, 64, 48]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[3]/ReLU[act]/14480, op type:nndct_relu, output shape: [1, 64, 64, 48]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[7]/ret.169, op type:nndct_elemwise_add, output shape: [1, 32, 32, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[7]/ReLU[act]/14692, op type:nndct_relu, output shape: [1, 32, 32, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[16]/ret.229, op type:nndct_elemwise_add, output shape: [1, 8, 8, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[16]/ReLU[act]/15149, op type:nndct_relu, output shape: [1, 8, 8, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[23]/ret.273, op type:nndct_elemwise_add, output shape: [1, 4, 4, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[23]/ReLU[act]/15482, op type:nndct_relu, output shape: [1, 4, 4, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[9]/ret.185, op type:nndct_elemwise_add, output shape: [1, 16, 16, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[9]/ReLU[act]/14816, op type:nndct_relu, output shape: [1, 16, 16, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[5]/ret.157, op type:nndct_elemwise_add, output shape: [1, 32, 32, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[5]/ReLU[act]/14604, op type:nndct_relu, output shape: [1, 32, 32, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone1]/BlazeBlock[4]/ret.29, op type:nndct_elemwise_add, output shape: [1, 64, 64, 48]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone1]/BlazeBlock[4]/ReLU[act]/13684, op type:nndct_relu, output shape: [1, 64, 64, 48]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone3]/BlazeBlock[2]/ret.71, op type:nndct_elemwise_add, output shape: [1, 16, 16, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone3]/BlazeBlock[2]/ReLU[act]/14009, op type:nndct_relu, output shape: [1, 16, 16, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[2]/ret.135, op type:nndct_elemwise_add, output shape: [1, 64, 64, 48]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[2]/ReLU[act]/14436, op type:nndct_relu, output shape: [1, 64, 64, 48]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[25]/ret.287, op type:nndct_elemwise_add, output shape: [1, 2, 2, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[25]/ReLU[act]/15595, op type:nndct_relu, output shape: [1, 2, 2, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone1]/BlazeBlock[3]/ret.19, op type:nndct_elemwise_add, output shape: [1, 128, 128, 24]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone1]/BlazeBlock[3]/ReLU[act]/13604, op type:nndct_relu, output shape: [1, 128, 128, 24]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[11]/ret.197, op type:nndct_elemwise_add, output shape: [1, 16, 16, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[11]/ReLU[act]/14904, op type:nndct_relu, output shape: [1, 16, 16, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone2]/BlazeBlock[2]/ret.51, op type:nndct_elemwise_add, output shape: [1, 32, 32, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone2]/BlazeBlock[2]/ReLU[act]/13852, op type:nndct_relu, output shape: [1, 32, 32, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[15]/ret.223, op type:nndct_elemwise_add, output shape: [1, 8, 8, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[15]/ReLU[act]/15105, op type:nndct_relu, output shape: [1, 8, 8, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[21]/ret.261, op type:nndct_elemwise_add, output shape: [1, 4, 4, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[21]/ReLU[act]/15394, op type:nndct_relu, output shape: [1, 4, 4, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone3]/BlazeBlock[1]/ret.63, op type:nndct_elemwise_add, output shape: [1, 32, 32, 96]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone3]/BlazeBlock[1]/ReLU[act]/13940, op type:nndct_relu, output shape: [1, 32, 32, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone1]/BlazeBlock[2]/ret.13, op type:nndct_elemwise_add, output shape: [1, 128, 128, 24]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone1]/BlazeBlock[2]/ReLU[act]/13560, op type:nndct_relu, output shape: [1, 128, 128, 24]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[18]/ret.241, op type:nndct_elemwise_add, output shape: [1, 8, 8, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[18]/ReLU[act]/15237, op type:nndct_relu, output shape: [1, 8, 8, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[10]/ret.191, op type:nndct_elemwise_add, output shape: [1, 16, 16, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[10]/ReLU[act]/14860, op type:nndct_relu, output shape: [1, 16, 16, 288]
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[12]/ret.203, op type:nndct_elemwise_add, output shape: [1, 16, 16, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[12]/ReLU[act]/14948, op type:nndct_relu, output shape: [1, 16, 16, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[19]/ret.249, op type:nndct_elemwise_add, output shape: [1, 4, 4, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[19]/ReLU[act]/15306, op type:nndct_relu, output shape: [1, 4, 4, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[1]/ret.129, op type:nndct_elemwise_add, output shape: [1, 64, 64, 48]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[1]/ReLU[act]/14392, op type:nndct_relu, output shape: [1, 64, 64, 48]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone2]/BlazeBlock[0]/ret.35, op type:nndct_elemwise_add, output shape: [1, 64, 64, 48]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone2]/BlazeBlock[0]/ReLU[act]/13728, op type:nndct_relu, output shape: [1, 64, 64, 48]
#
#
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_23:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[13]/ret.209, op type:nndct_elemwise_add, output shape: [1, 16, 16, 288]
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[13]/ReLU[act]/14992, op type:nndct_relu, output shape: [1, 16, 16, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for pad_fix_0:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[4]/ret.143, op type:nndct_pad_nd, output shape: [1, 67, 67, 48]
#
#
#
# [VAIQ_NOTE]: Find subgraph for pad_fix_0:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone4]/BlazeBlock[2]/ret.85, op type:nndct_pad_nd, output shape: [1, 19, 19, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for pad_fix_0:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[14]/ret.211, op type:nndct_pad_nd, output shape: [1, 19, 19, 288]
#
#
#
# [VAIQ_NOTE]: Find subgraph for pad_fix_0:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone2]/BlazeBlock[2]/ret.45, op type:nndct_pad_nd, output shape: [1, 32, 32, 96]
#
#
#
# [VAIQ_NOTE]: Find subgraph for pad_fix_0:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone2]/BlazeBlock[2]/ret.43, op type:nndct_pad_nd, output shape: [1, 67, 67, 48]
#
#
#
# [VAIQ_NOTE]: Find subgraph for pad_fix_0:
# node name:BlazeHandLandmark::BlazeHandLandmark/ret.5, op type:nndct_pad_nd, output shape: [1, 257, 257, 3]
#
#
#
# [VAIQ_NOTE]: Find subgraph for pad_fix_0:
# node name:BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone1]/BlazeBlock[4]/ret.23, op type:nndct_pad_nd, output shape: [1, 64, 64, 48]
# I20240114 12:05:55.373181   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.373203   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.373207   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.373287   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_iMevJp0FS32sqtlG, with op num: 7
# I20240114 12:05:55.373291   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.376161   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.376188   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.380548   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.380564   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.380570   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.380640   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_5xta2nh7l4CV01SZ, with op num: 7
# I20240114 12:05:55.380646   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.383641   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.383666   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.386893   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.386906   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.386910   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.386963   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_FsjiQb3hmaS760fK, with op num: 7
# I20240114 12:05:55.386967   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.390208   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.390233   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.392866   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.392879   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.392882   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.392935   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_HMsvtQFKbzolAOR6, with op num: 7
# I20240114 12:05:55.392939   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.395740   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.395763   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.398139   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.398152   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.398155   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.398201   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_wie46bOkFPX3BlRD, with op num: 7
# I20240114 12:05:55.398205   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.401080   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.401106   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.404248   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.404265   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.404269   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.404335   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_FrASGMfvhDiBOt59, with op num: 7
# I20240114 12:05:55.404337   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.407265   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.407290   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.409760   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.409773   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.409777   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.409832   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_l8Cgy6u4iNfpFWZn, with op num: 7
# I20240114 12:05:55.409835   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.412700   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.412725   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.415130   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.415144   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.415148   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.415199   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_dbiDXGPkJLuHcFZV, with op num: 7
# I20240114 12:05:55.415202   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.418545   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.418579   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.421339   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.421352   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.421356   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.421409   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_jOLeG60hgkzfJ4t3, with op num: 7
# I20240114 12:05:55.421413   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.424407   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.424433   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.427052   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.427067   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.427071   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.427126   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_xKXJV6Bdy94MSsot, with op num: 7
# I20240114 12:05:55.427129   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.429970   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.429993   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.432713   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.432726   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.432730   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.432785   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_Vq4O8TwE1YKvmkDs, with op num: 7
# I20240114 12:05:55.432788   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.435802   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.435838   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.438912   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.438930   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.438935   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.438999   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_sLQMDFPI0peYciVf, with op num: 7
# I20240114 12:05:55.439002   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.442027   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.442054   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.444617   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.444633   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.444636   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.444689   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_Q2lMuxJZ1kCR3Ycm, with op num: 7
# I20240114 12:05:55.444692   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.447918   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.447945   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.451354   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.451375   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.451380   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.451457   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_yuTwKIMo63VHUYSZ, with op num: 7
# I20240114 12:05:55.451462   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.455766   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.455798   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.458768   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.458854   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.458861   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.458925   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_pD0456m2oOITGNZw, with op num: 7
# I20240114 12:05:55.458930   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.461796   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.461820   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.464399   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.464411   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.464416   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.464469   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_kD5HM1UaPZizCpjw, with op num: 7
# I20240114 12:05:55.464473   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.468575   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.468611   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.471698   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.471715   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.471719   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.471782   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_FNXGTAaRW26dlqeD, with op num: 7
# I20240114 12:05:55.471786   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.474758   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.474784   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.477319   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.477330   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.477334   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.477388   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_zmFMexuTACOUEnKN, with op num: 7
# I20240114 12:05:55.477392   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.480233   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.480257   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.482873   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.482890   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.482896   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.482959   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_4fxsP01mhEyLHKNq, with op num: 7
# I20240114 12:05:55.482964   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.486379   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.486408   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.489220   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.489233   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.489236   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.489291   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_zLtZfOjMslS6Deai, with op num: 7
# I20240114 12:05:55.489295   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.492250   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.492275   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.495036   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.495050   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.495054   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.495112   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_QelSMrBjxJukmOLU, with op num: 7
# I20240114 12:05:55.495115   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.498041   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.498066   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.501128   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.501150   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.501155   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:55.501230   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_nndct_relu_MHIgb2adPE3W0K5h, with op num: 7
# I20240114 12:05:55.501235   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:55.505760   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:55.505795   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:55.508699   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:55.508716   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:55.508720   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# ...
# BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone2]/BlazeBlock[2]/ret.45    nndct_pad_nd        xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone2__BlazeBlock_2__ret_45, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone3]/BlazeBlock[2]/ret.65    nndct_pad_nd        xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone3__BlazeBlock_2__ret_65, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone4]/BlazeBlock[2]/ret.85    nndct_pad_nd        xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone4__BlazeBlock_2__ret_85, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[4]/ret.143   nndct_pad_nd        xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_4__ret_143, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[4]/ret.145   nndct_pad_nd        xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_4__ret_145, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[9]/ret.177   nndct_pad_nd        xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_9__ret_177, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[9]/ret.179   nndct_pad_nd        xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_9__ret_179, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[14]/ret.211  nndct_pad_nd        xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_14__ret_211, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[19]/ret.243  nndct_pad_nd        xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_19__ret_243, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[24]/ret.275  nndct_pad_nd        xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_24__ret_275, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# BlazeHandLandmark::BlazeHandLandmark/ret.311                                       nndct_sigmoid       nndct_sigmoid can't be assigned to DPU.
# BlazeHandLandmark::BlazeHandLandmark/ret.317                                       nndct_sigmoid       nndct_sigmoid can't be assigned to DPU.
# BlazeHandLandmark::BlazeHandLandmark/ret                                           nndct_elemwise_div  xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_ret_new, type = eltwise-fix} has been assigned to CPU: [DPUCZDX8G_ISA1_B4096 does not support eltwise DIV].
#
# [VAIQ_NOTE]: =>Finish inspecting.
# I20240114 12:05:56.419505   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.419566   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_depthwise_conv2d_0J2ONiaWFvV4Qcn5, with op num: 8
# I20240114 12:05:56.419571   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.424010   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20240114 12:05:56.424036   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.427343   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.427356   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.427359   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.427413   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_depthwise_conv2d_4elKjgr3dOMJCkY8, with op num: 8
# I20240114 12:05:56.427417   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.431553   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20240114 12:05:56.431578   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.434609   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.434623   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.434626   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.434680   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_depthwise_conv2d_2wV1MDW49IKa5iXs, with op num: 8
# I20240114 12:05:56.434684   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.438860   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20240114 12:05:56.438885   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.442775   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.442792   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.442797   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.442864   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_depthwise_conv2d_2qPEcgvaWxF5y9fo, with op num: 8
# I20240114 12:05:56.442869   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.447260   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20240114 12:05:56.447286   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.451328   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.451350   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.451356   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.451426   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_depthwise_conv2d_J4E1oKc5p2bqu9Pd, with op num: 8
# I20240114 12:05:56.451431   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.458693   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20240114 12:05:56.458732   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.462330   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.462347   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.462352   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.462410   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_depthwise_conv2d_PWs8cXE6QjNwHOiS, with op num: 8
# I20240114 12:05:56.462414   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.467397   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20240114 12:05:56.467434   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.470817   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.470834   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.470837   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.470894   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_depthwise_conv2d_WR2iM7nfp6zHYsyI, with op num: 8
# I20240114 12:05:56.470898   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.475281   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20240114 12:05:56.475306   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.478104   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.478118   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.478122   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.478174   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_depthwise_conv2d_Fn5oqQ48rPvGcy2h, with op num: 8
# I20240114 12:05:56.478178   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.482542   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20240114 12:05:56.482569   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.485826   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.485843   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.485848   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.485908   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_depthwise_conv2d_tvWV1gzabmCsM4Ud, with op num: 8
# I20240114 12:05:56.485911   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.490141   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20240114 12:05:56.490170   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.493232   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.493247   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.493250   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.493305   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_depthwise_conv2d_qLl7V9WphbZ3nPOD, with op num: 8
# I20240114 12:05:56.493309   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.497460   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20240114 12:05:56.497485   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.500313   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.500326   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.500329   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.500381   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_depthwise_conv2d_4VqDOZb2nNjU8pCJ, with op num: 8
# I20240114 12:05:56.500385   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.504813   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20240114 12:05:56.504839   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.516173   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.516192   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.516197   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.516275   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_8Ws7OIZgjoCVycrp, with op num: 6
# I20240114 12:05:56.516280   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.520200   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:56.520237   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.523435   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.523450   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.523453   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.523515   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_XS8Q06NhuvwEsH2V, with op num: 6
# I20240114 12:05:56.523519   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.526224   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:56.526250   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.528649   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.528662   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.528666   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.528718   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_LM5cOd0JHrUnPkTN, with op num: 6
# I20240114 12:05:56.528723   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20240114 12:05:56.531275   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20240114 12:05:56.531298   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20240114 12:05:56.533738   223 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20240114 12:05:56.533751   223 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20240114 12:05:56.533754   223 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# I20240114 12:05:56.533808   223 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_div_3tv0QlEcx7XuOUJ1, with op num: 6
# I20240114 12:05:56.533811   223 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20240114 12:05:56.536618   223 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_ret_new, type = eltwise-fix} has been assigned to CPU: [DPUCZDX8G_ISA1_B4096 does not support eltwise DIV].
# I20240114 12:05:56.536687   223 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20240114 12:05:56.536705   223 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.

# %% [markdown]
# ## 3. Quantization
# In order to compile the trained model for deployment on a DPU platform, we must first quantize it. Here we will use the `vitis_quantize` module to convert the floating point model into an INT8 quantized representation.

# %% [markdown]
# ***Quantize - Calibration Phase***

# %% [markdown]
# **Quantize model**
#
# By default the `quantize_model` function converts the weights, activations and inputs into 8-bit wide numbers. We can specify different values and configurations using `weight_bit`, `activation_bit` and other parameters.

# %%
from pytorch_nndct.apis import torch_quantizer, dump_xmodel

# %%
quant_mode = 'calib'
batchsize = 100
quant_model = './model_blazehandlandmark11_quant'

# %%
# force to merge BN with CONV for better quantization accuracy
optimize = 1

# override batchsize if in test mode
if (quant_mode=='test'):
  batchsize = 1
  
rand_in = torch.randn([batchsize, 3,256,256])
print("rand_in.shape=",rand_in.shape)
quantizer = torch_quantizer(quant_mode, model, (rand_in), output_dir=quant_model, device=device) 
quantized_model = quantizer.quant_model
# Out:
# rand_in.shape= torch.Size([100, 3, 256, 256])
#
# [VAIQ_NOTE]: OS and CPU information:
#                system --- Linux
#                  node --- albertabeef-HP-Z4-G4-Workstation
#               release --- 5.14.0-1055-oem
#               version --- #62-Ubuntu SMP Wed Nov 30 04:54:03 UTC 2022
#               machine --- x86_64
#             processor --- x86_64
#
# [VAIQ_NOTE]: Tools version information:
#                   GCC --- GCC 7.5.0
#                python --- 3.8.6
#               pytorch --- 1.13.1
#         vai_q_pytorch --- 3.5.0+60df3f1+torch1.13.1
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization calibration process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cpu'.
#
# [VAIQ_NOTE]: =>Parsing BlazeHandLandmark...
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model nndct_st_BlazeHandLandmark_ed is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 216/216 [00:00<00:00, 1026.9
# [VAIQ_NOTE]: =>Doing weights equalization...
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(./model_blazehandlandmark11_quant/BlazeHandLandmark.py)
#
# [VAIQ_NOTE]: =>Get module with quantization.

# %% [markdown]
# **Evaluate quantized model**
#
# In order to evaluate the quantized model, it needs to be re-compiled with the desired loss and evaluation metrics, such as accuracy. Since we are using 8-bit quantization we do not lose much performance, if at all.

# %%
#acc1_gen, acc5_gen, loss_gen = evaluate(quantized_model, val_loader, loss_fn)

# reference : https://github.com/Xilinx/Vitis-AI/blob/master/src/vai_quantizer/vai_q_pytorch/example/resnet18_quant.py
quantized_model.eval()
quantized_model = quantized_model.to(device)
batchsize=1
inputs = torch.randn([batchsize, 3,256,256])
print("inputs.shape=",inputs.shape)
outputs = quantized_model(inputs)
print("len(outputs)=",len(outputs))
for i in range(len(outputs)):
    print("outputs[",i,"].shape=",outputs[i].shape)
# Out:
# inputs.shape= torch.Size([1, 3, 256, 256])
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.8/site-packages/pytorch_nndct/quantization/torchquantizer.py:223: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   bnfp[1] = stats.mode(data)[0][0]
# len(outputs)= 3
# outputs[ 0 ].shape= torch.Size([1])
# outputs[ 1 ].shape= torch.Size([1])
# outputs[ 2 ].shape= torch.Size([1, 21, 3])

# %%
if quant_mode == 'calib':
    quantizer.export_quant_config()
# Out:
# [VAIQ_NOTE]: =>Exporting quant config.(./model_blazehandlandmark11_quant/quant_info.json)

# %% [markdown]
# ***Quantize - Test Phase***

# %% [markdown]
# **Save quantized model**
#
# Once we are happy with the performance of the quantized model, we can save it as a .h5 file, simply using the `save` method.

# %%
quant_mode = 'test'
batchsize = 1
quant_model = './model_blazehandlandmark11_quant'

# %%
rand_in = torch.randn([batchsize, 3,256,256])
print(rand_in.shape)
quantizer = torch_quantizer(quant_mode, model, (rand_in), output_dir=quant_model, device=device) 
quantized_model = quantizer.quant_model
# Out:
# torch.Size([1, 3, 256, 256])
#
# [VAIQ_NOTE]: OS and CPU information:
#                system --- Linux
#                  node --- albertabeef-HP-Z4-G4-Workstation
#               release --- 5.14.0-1055-oem
#               version --- #62-Ubuntu SMP Wed Nov 30 04:54:03 UTC 2022
#               machine --- x86_64
#             processor --- x86_64
#
# [VAIQ_NOTE]: Tools version information:
#                   GCC --- GCC 7.5.0
#                python --- 3.8.6
#               pytorch --- 1.13.1
#         vai_q_pytorch --- 3.5.0+60df3f1+torch1.13.1
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization test process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cpu'.
#
# [VAIQ_NOTE]: =>Parsing BlazeHandLandmark...
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model nndct_st_BlazeHandLandmark_ed is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 216/216 [00:00<00:00, 1126.7
# [VAIQ_NOTE]: =>Doing weights equalization...
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(./model_blazehandlandmark11_quant/BlazeHandLandmark.py)
#
# [VAIQ_NOTE]: =>Get module with quantization.

# %%
# reference : https://github.com/Xilinx/Vitis-AI/blob/master/src/vai_quantizer/vai_q_pytorch/example/resnet18_quant.py
quantized_model.eval()
quantized_model = quantized_model.to(device)
inputs = torch.randn([batchsize, 3,256,256])
print("inputs.shape=",inputs.shape)
outputs = quantized_model(inputs)
print("len(outputs)=",len(outputs))
for i in range(len(outputs)):
    print("outputs[",i,"].shape=",outputs[i].shape)
# Out:
# inputs.shape= torch.Size([1, 3, 256, 256])
# len(outputs)= 3
# outputs[ 0 ].shape= torch.Size([1])
# outputs[ 1 ].shape= torch.Size([1])
# outputs[ 2 ].shape= torch.Size([1, 21, 3])

# %%
quantizer.export_torch_script()
# Out:
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.8/site-packages/pytorch_nndct/nn/modules/module_template.py:132: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   output = caller(*args, **kwargs)
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.8/site-packages/pytorch_nndct/quantization/quantizerimpl.py:17: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if inf.sum() > 0 or nan.sum() > 0:
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.8/site-packages/pytorch_nndct/nn/modules/fix_ops.py:67: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if (isinstance(tensor, torch.Tensor) and
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.8/site-packages/pytorch_nndct/nn/modules/prim_ops.py:116: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if not (list(self.node.out_tensors[0].shape[1:]) == list(input.size())[1:]):
# [VAIQ_NOTE]: BlazeHandLandmark_int.pt is generated.(quantize_result/BlazeHandLandmark_int.pt)
# BlazeHandLandmark(
#   original_name=BlazeHandLandmark
#   (module_0): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_1): deephi_Input(original_name=deephi_Input)
#   (module_2): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_3): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_4): deephi_ReLU(original_name=deephi_ReLU)
#   (module_5): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_6): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_7): deephi_Add(original_name=deephi_Add)
#   (module_8): deephi_ReLU(original_name=deephi_ReLU)
#   (module_9): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_10): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_11): deephi_Add(original_name=deephi_Add)
#   (module_12): deephi_ReLU(original_name=deephi_ReLU)
#   (module_13): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_14): deephi_MaxPool2d(original_name=deephi_MaxPool2d)
#   (module_15): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_16): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_17): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_18): deephi_Add(original_name=deephi_Add)
#   (module_19): deephi_ReLU(original_name=deephi_ReLU)
#   (module_20): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_21): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_22): deephi_Add(original_name=deephi_Add)
#   (module_23): deephi_ReLU(original_name=deephi_ReLU)
#   (module_24): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_25): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_26): deephi_Add(original_name=deephi_Add)
#   (module_27): deephi_ReLU(original_name=deephi_ReLU)
#   (module_28): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_29): deephi_MaxPool2d(original_name=deephi_MaxPool2d)
#   (module_30): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_31): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_32): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_33): deephi_Add(original_name=deephi_Add)
#   (module_34): deephi_ReLU(original_name=deephi_ReLU)
#   (module_35): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_36): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_37): deephi_Add(original_name=deephi_Add)
#   (module_38): deephi_ReLU(original_name=deephi_ReLU)
#   (module_39): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_40): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_41): deephi_Add(original_name=deephi_Add)
#   (module_42): deephi_ReLU(original_name=deephi_ReLU)
#   (module_43): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_44): deephi_MaxPool2d(original_name=deephi_MaxPool2d)
#   (module_45): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_46): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_47): deephi_Add(original_name=deephi_Add)
#   (module_48): deephi_ReLU(original_name=deephi_ReLU)
#   (module_49): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_50): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_51): deephi_Add(original_name=deephi_Add)
#   (module_52): deephi_ReLU(original_name=deephi_ReLU)
#   (module_53): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_54): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_55): deephi_Add(original_name=deephi_Add)
#   (module_56): deephi_ReLU(original_name=deephi_ReLU)
#   (module_57): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_58): deephi_MaxPool2d(original_name=deephi_MaxPool2d)
#   (module_59): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_60): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_61): deephi_Add(original_name=deephi_Add)
#   (module_62): deephi_ReLU(original_name=deephi_ReLU)
#   (module_63): deephi_Interpolate(original_name=deephi_Interpolate)
#   (module_64): deephi_Add(original_name=deephi_Add)
#   (module_65): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_66): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_67): deephi_Add(original_name=deephi_Add)
#   (module_68): deephi_ReLU(original_name=deephi_ReLU)
#   (module_69): deephi_Interpolate(original_name=deephi_Interpolate)
#   (module_70): deephi_Add(original_name=deephi_Add)
#   (module_71): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_72): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_73): deephi_Add(original_name=deephi_Add)
#   (module_74): deephi_ReLU(original_name=deephi_ReLU)
#   (module_75): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_76): deephi_Interpolate(original_name=deephi_Interpolate)
#   (module_77): deephi_Add(original_name=deephi_Add)
#   (module_78): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_79): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_80): deephi_Add(original_name=deephi_Add)
#   (module_81): deephi_ReLU(original_name=deephi_ReLU)
#   (module_82): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_83): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_84): deephi_Add(original_name=deephi_Add)
#   (module_85): deephi_ReLU(original_name=deephi_ReLU)
#   (module_86): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_87): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_88): deephi_Add(original_name=deephi_Add)
#   (module_89): deephi_ReLU(original_name=deephi_ReLU)
#   (module_90): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_91): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_92): deephi_Add(original_name=deephi_Add)
#   (module_93): deephi_ReLU(original_name=deephi_ReLU)
#   (module_94): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_95): deephi_MaxPool2d(original_name=deephi_MaxPool2d)
#   (module_96): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_97): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_98): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_99): deephi_Add(original_name=deephi_Add)
#   (module_100): deephi_ReLU(original_name=deephi_ReLU)
#   (module_101): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_102): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_103): deephi_Add(original_name=deephi_Add)
#   (module_104): deephi_ReLU(original_name=deephi_ReLU)
#   (module_105): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_106): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_107): deephi_Add(original_name=deephi_Add)
#   (module_108): deephi_ReLU(original_name=deephi_ReLU)
#   (module_109): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_110): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_111): deephi_Add(original_name=deephi_Add)
#   (module_112): deephi_ReLU(original_name=deephi_ReLU)
#   (module_113): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_114): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_115): deephi_Add(original_name=deephi_Add)
#   (module_116): deephi_ReLU(original_name=deephi_ReLU)
#   (module_117): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_118): deephi_MaxPool2d(original_name=deephi_MaxPool2d)
#   (module_119): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_120): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_121): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_122): deephi_Add(original_name=deephi_Add)
#   (module_123): deephi_ReLU(original_name=deephi_ReLU)
#   (module_124): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_125): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_126): deephi_Add(original_name=deephi_Add)
#   (module_127): deephi_ReLU(original_name=deephi_ReLU)
#   (module_128): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_129): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_130): deephi_Add(original_name=deephi_Add)
#   (module_131): deephi_ReLU(original_name=deephi_ReLU)
#   (module_132): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_133): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_134): deephi_Add(original_name=deephi_Add)
#   (module_135): deephi_ReLU(original_name=deephi_ReLU)
#   (module_136): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_137): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_138): deephi_Add(original_name=deephi_Add)
#   (module_139): deephi_ReLU(original_name=deephi_ReLU)
#   (module_140): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_141): deephi_MaxPool2d(original_name=deephi_MaxPool2d)
#   (module_142): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_143): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_144): deephi_Add(original_name=deephi_Add)
#   (module_145): deephi_ReLU(original_name=deephi_ReLU)
#   (module_146): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_147): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_148): deephi_Add(original_name=deephi_Add)
#   (module_149): deephi_ReLU(original_name=deephi_ReLU)
#   (module_150): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_151): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_152): deephi_Add(original_name=deephi_Add)
#   (module_153): deephi_ReLU(original_name=deephi_ReLU)
#   (module_154): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_155): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_156): deephi_Add(original_name=deephi_Add)
#   (module_157): deephi_ReLU(original_name=deephi_ReLU)
#   (module_158): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_159): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_160): deephi_Add(original_name=deephi_Add)
#   (module_161): deephi_ReLU(original_name=deephi_ReLU)
#   (module_162): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_163): deephi_MaxPool2d(original_name=deephi_MaxPool2d)
#   (module_164): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_165): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_166): deephi_Add(original_name=deephi_Add)
#   (module_167): deephi_ReLU(original_name=deephi_ReLU)
#   (module_168): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_169): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_170): deephi_Add(original_name=deephi_Add)
#   (module_171): deephi_ReLU(original_name=deephi_ReLU)
#   (module_172): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_173): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_174): deephi_Add(original_name=deephi_Add)
#   (module_175): deephi_ReLU(original_name=deephi_ReLU)
#   (module_176): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_177): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_178): deephi_Add(original_name=deephi_Add)
#   (module_179): deephi_ReLU(original_name=deephi_ReLU)
#   (module_180): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_181): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_182): deephi_Add(original_name=deephi_Add)
#   (module_183): deephi_ReLU(original_name=deephi_ReLU)
#   (module_184): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_185): deephi_MaxPool2d(original_name=deephi_MaxPool2d)
#   (module_186): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_187): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_188): deephi_Add(original_name=deephi_Add)
#   (module_189): deephi_ReLU(original_name=deephi_ReLU)
#   (module_190): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_191): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_192): deephi_Add(original_name=deephi_Add)
#   (module_193): deephi_ReLU(original_name=deephi_ReLU)
#   (module_194): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_195): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_196): deephi_Add(original_name=deephi_Add)
#   (module_197): deephi_ReLU(original_name=deephi_ReLU)
#   (module_198): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_199): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_200): deephi_Add(original_name=deephi_Add)
#   (module_201): deephi_ReLU(original_name=deephi_ReLU)
#   (module_202): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_203): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_204): deephi_Add(original_name=deephi_Add)
#   (module_205): deephi_ReLU(original_name=deephi_ReLU)
#   (module_206): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_207): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_208): deephi_Sigmoid(original_name=deephi_Sigmoid)
#   (module_209): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_210): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_211): deephi_Sigmoid(original_name=deephi_Sigmoid)
#   (module_212): deephi_Conv2d(original_name=deephi_Conv2d)
#   (module_213): DeephiFuncModule(original_name=DeephiFuncModule)
#   (module_214): DeephiFuncModule(original_name=DeephiFuncModule)
# )

# %%
quantizer.export_onnx_model()
# Out:
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.8/site-packages/torch/onnx/_internal/jit_utils.py:258: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525491394/work/torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.8/site-packages/torch/onnx/_internal/jit_utils.py:258: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525491394/work/torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.8/site-packages/torch/onnx/utils.py:687: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525491394/work/torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.8/site-packages/torch/onnx/utils.py:687: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525491394/work/torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# [VAIQ_NOTE]: BlazeHandLandmark_int.onnx is generated.(quantize_result/BlazeHandLandmark_int.onnx)
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.8/site-packages/torch/onnx/utils.py:1178: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525491394/work/torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.8/site-packages/torch/onnx/utils.py:1178: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525491394/work/torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_graph_shape_type_inference(

# %%
quantizer.export_xmodel(deploy_check=False)
# Out:
# [VAIQ_NOTE]: =>Converting to xmodel ...
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/ret.5) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone1]/BlazeBlock[4]/ret.21) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone2]/BlazeBlock[2]/ret.43) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone3]/BlazeBlock[2]/ret.65) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone4]/BlazeBlock[2]/ret.85) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[4]/ret.143) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[9]/ret.177) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[14]/ret.211) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[19]/ret.243) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[24]/ret.275) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[9]/ret.179) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone8]/BlazeBlock[4]/ret.145) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone2]/BlazeBlock[2]/ret.45) can't be fused
#
# [VAIQ_WARN]: Pad(BlazeHandLandmark::BlazeHandLandmark/Sequential[backbone1]/BlazeBlock[4]/ret.23) can't be fused
#
# [VAIQ_NOTE]: =>Successfully convert 'BlazeHandLandmark' to xmodel.(quantize_result/BlazeHandLandmark_int.xmodel)

# %% [markdown]
# ## 4. Compilation
#
# For this final step we use the Vitis AI compiler `vai_c_pytorch` and pass the quantized model as a parameter. In this example we are compiling the DPU model targeting the KV260 board, however to target a different board you will just have to point the compiler to the right `arch.json` file.
#
# For example, for the ZCU104 you would pass
#
# `--arch /opt/vitis_ai/compiler/arch/DPUCZDX8G/ZCU104/arch.json`
#
# and for Ultra96, we can pass the custom arch.json in this repository
#
# `--arch ./arch.json`

# %%
# vai_c_xir -x /PATH/TO/quantized.xmodel -a /PATH/TO/arch.json -o /OUTPUTPATH -n netname

# %%
# !vai_c_xir \
    -x ./quantize_result/BlazeHandLandmark_int.xmodel \
    -a ./arch/B4096/arch-zcu104.json \
    -o ./models_blaze/B4096 \
    -n blazehandlandmark

# !vai_c_xir \
    -x ./quantize_result/BlazeHandLandmark_int.xmodel \
    -a ./arch/B3136/arch-kv260.json \
    -o ./models_blaze/B3136 \
    -n blazehandlandmark

# !vai_c_xir \
    -x ./quantize_result/BlazeHandLandmark_int.xmodel \
    -a ./arch/B2304/arch-b2304-lr.json \
    -o ./models_blaze/B2304 \
    -n blazehandlandmark

# !vai_c_xir \
    -x ./quantize_result/BlazeHandLandmark_int.xmodel \
    -a ./arch/B1152/arch-b1152-hr.json \
    -o ./models_blaze/B1152 \
    -n blazehandlandmark

# !vai_c_xir \
    -x ./quantize_result/BlazeHandLandmark_int.xmodel \
    -a ./arch/B512/arch-b512-lr.json \
    -o ./models_blaze/B512 \
    -n blazehandlandmark

# !vai_c_xir \
    -x ./quantize_result/BlazeHandLandmark_int.xmodel \
    -a ./arch/B128/arch-b128-lr.json \
    -o ./models_blaze/B128 \
    -n blazehandlandmark
# Out:
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: null
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B4096
# [UNILOG][INFO] Graph name: BlazeHandLandmark, with op num: 753
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone1__BlazeBlock_4__ret_23, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone2__BlazeBlock_2__ret_45, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_4__ret_145, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_9__ret_179, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_ret_new, type = eltwise-fix} has been assigned to CPU: [DPUCZDX8G_ISA1_B4096 does not support eltwise DIV].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__16234, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 13, DPU subgraph number 5
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B4096/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B4096/blazehandlandmark.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is e51cba9ee87acd4d2f0571003c1515af, and has been saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B4096/md5sum.txt"
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: null
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B3136
# [UNILOG][INFO] Graph name: BlazeHandLandmark, with op num: 753
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone1__BlazeBlock_4__ret_23, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone2__BlazeBlock_2__ret_45, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_4__ret_145, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_9__ret_179, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_ret_new, type = eltwise-fix} has been assigned to CPU: [DPUCZDX8G_ISA1_B3136 does not support eltwise DIV].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__16234, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 13, DPU subgraph number 5
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B3136/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B3136/blazehandlandmark.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is ac8551da68e47f4252cfc6c0e3db21ce, and has been saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B3136/md5sum.txt"
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: null
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B2304_0101000016010405
# [UNILOG][INFO] Graph name: BlazeHandLandmark, with op num: 753
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone1__BlazeBlock_4__ret_23, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone2__BlazeBlock_2__ret_45, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_4__ret_145, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_9__ret_179, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_ret_new, type = eltwise-fix} has been assigned to CPU: [DPUCZDX8G_ISA1_B2304_0101000016010405 does not support eltwise DIV].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__16234, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 13, DPU subgraph number 5
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B2304/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B2304/blazehandlandmark.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 6d7f98052e0dc82a30c165b1b5faaf3a, and has been saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B2304/md5sum.txt"
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: null
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B1152_0101000017010203
# [UNILOG][INFO] Graph name: BlazeHandLandmark, with op num: 753
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone1__BlazeBlock_4__ret_23, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone2__BlazeBlock_2__ret_45, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_4__ret_145, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_9__ret_179, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_ret_new, type = eltwise-fix} has been assigned to CPU: [DPUCZDX8G_ISA1_B1152_0101000017010203 does not support eltwise DIV].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__16234, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 13, DPU subgraph number 5
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B1152/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B1152/blazehandlandmark.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is e54615a02abf52f597429d9c3515653f, and has been saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B1152/md5sum.txt"
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: null
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B512_0101000016010200
# [UNILOG][INFO] Graph name: BlazeHandLandmark, with op num: 753
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone1__BlazeBlock_4__ret_23, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone2__BlazeBlock_2__ret_45, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_4__ret_145, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_9__ret_179, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_ret_new, type = eltwise-fix} has been assigned to CPU: [DPUCZDX8G_ISA1_B512_0101000016010200 does not support eltwise DIV].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__16234, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 13, DPU subgraph number 5
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B512/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B512/blazehandlandmark.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 8bce2653cd43c7251eeb2dec537563fd, and has been saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B512/md5sum.txt"
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: null
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA1_B128_0101000002010208
# [UNILOG][INFO] Graph name: BlazeHandLandmark, with op num: 753
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone1__BlazeBlock_4__ret_23, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone2__BlazeBlock_2__ret_45, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_4__ret_145, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_9__ret_179, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_ret_new, type = eltwise-fix} has been assigned to CPU: [DPUCZDX8G_ISA1_B128_0101000002010208 does not support eltwise DIV].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__16234, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 13, DPU subgraph number 5
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B128/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B128/blazehandlandmark.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 60cf2ab8f690f126d7db92f2c2948ef4, and has been saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/B128/md5sum.txt"

# %%
# !vai_c_xir \
    -x ./quantize_result/BlazeHandLandmark_int.xmodel \
    -a ./arch/C20B14/arch-c20b14.json \
    -o ./models_blaze/C20B14 \
    -n blazehandlandmark

# !vai_c_xir \
    -x ./quantize_result/BlazeHandLandmark_int.xmodel \
    -a ./arch/C20B1/arch-c20b1.json \
    -o ./models_blaze/C20B1 \
    -n blazehandlandmark
# Out:
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: null
# [UNILOG][INFO] Target architecture: DPUCV2DX8G_ISA1_C20B14
# [UNILOG][INFO] Graph name: BlazeHandLandmark, with op num: 753
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone1__BlazeBlock_4__ret_23, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone2__BlazeBlock_2__ret_45, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_4__ret_145, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_9__ret_179, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_ret_new, type = eltwise-fix} has been assigned to CPU: [DPUCV2DX8G_ISA1_C20B14 does not support eltwise DIV].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__16234, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 13, DPU subgraph number 5
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/C20B14/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/C20B14/blazehandlandmark.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 91bfe278940a4e454f5de077d988adf7, and has been saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/C20B14/md5sum.txt"
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: null
# [UNILOG][INFO] Target architecture: DPUCV2DX8G_ISA1_C20B1
# [UNILOG][INFO] Graph name: BlazeHandLandmark, with op num: 753
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone1__BlazeBlock_4__ret_23, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone2__BlazeBlock_2__ret_45, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_4__ret_145, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_Sequential_backbone8__BlazeBlock_9__ret_179, type = pad-fix} has been assigned to CPU: [DPU does not support CONSTANT mode. (only support SYMMETRIC mode for all devices and CONSTANT mode for some DPUv4e devices)].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__BlazeHandLandmark_ret_new, type = eltwise-fix} has been assigned to CPU: [DPUCV2DX8G_ISA1_C20B1 does not support eltwise DIV].
# [UNILOG][WARNING] xir::Op{name = BlazeHandLandmark__16234, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 13, DPU subgraph number 5
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/C20B1/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/C20B1/blazehandlandmark.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 2efa09a9f2054f30e489b2b6675f8b3c, and has been saved to "/workspace/blaze_tutorial/vitis-ai/./models_blaze/C20B1/md5sum.txt"

# %% [markdown]
# ----
#
# Copyright (C) 2024 Avnet, Inc
#
# SPDX-License-Identifier: Apache-2.0 License
#
# ----
#
# ----
